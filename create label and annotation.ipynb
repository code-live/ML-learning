# %%
import numpy as np
from numpy.random import randn
import pandas as pd
from pandas import Series, DataFrame

import matplotlib.pyplot as plt
from  matplotlib import rcParams
import seaborn as sb

# %%
# %matplotlib inline
rcParams['figure.figsize'] = 8, 4
sb.set_style('whitegrid')

# %%
x = range(1,10)
y = [1,2,3,4,1,3,2,1,4]
plt.bar(x, y)

plt.xlabel('your x-label')
plt.ylabel('your y-label')
# Out:
# Text(0,0.5,'your y-label')

# %%
z = [1,2,3,4,.5]
veh_type = ['bicycle','motor','car','van','bike']
plt.pie(z, labels=veh_type)
plt.show()

# %%
address = "/Users/virendsingh/Downloads/Ex_Files_Python_Data_Science_EssT/Exercise Files/Ch01/01_05/mtcars.csv"
cars = pd.read_csv(address)
cars.columns = ['car_names','mpg','cyl','disp','hp','drat','wt','qsec','vs','am','gear','carb']
mpg = cars.mpg
fig = plt.figure()
ax = fig.add_axes([.1,.1,1,1])
mpg.plot()
ax.set_xticks(range(32))
ax.set_xticklabels(cars.car_names, rotation=60, fontsize='medium')
ax.set_title("miles per gallon for cars")
ax.set_xlabel('car names')
ax.set_ylabel('miles')
# Out:
# Text(0,0.5,'miles')

# %%
plt.pie(z)
plt.legend(veh_type, loc="best")
plt.show()

# %%
fig = plt.figure()
ax = fig.add_axes([.1,.1,1,1])
mpg.plot()
ax.set_xticks(range(32))
ax.set_xticklabels(cars.car_names, rotation=60, fontsize='medium')
ax.set_title("miles per gallon for cars")
ax.set_xlabel('car names')
ax.set_ylabel('miles')
ax.legend(loc="best")

# %%
mpg.max()
# Out:
# 33.9

# %%
fig = plt.figure()
ax = fig.add_axes([.1,.1,1,1])
mpg.plot()
ax.set_xticks(range(32))
ax.set_xticklabels(cars.car_names, rotation=60, fontsize='medium')
ax.set_title("miles per gallon for cars")
ax.set_xlabel('car names')
ax.set_ylabel('miles')
ax.set_ylim([0,45])
ax.annotate('Toyota', xy=(19, 33.9), xytext=(22, 35),
           arrowprops=dict(facecolor='black', shrink=0.05))
# Out:
# Text(22,35,'Toyota')
